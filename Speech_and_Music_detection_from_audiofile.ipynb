# %% [markdown]
# <a href="https://colab.research.google.com/github/JAYANTHNITW/Youtube-Video-Automation-Using-LLMs/blob/main/Speech_and_Music_detection_from_audiofile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 52.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 92.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.3 MB/s eta 0:00:00
# ...

# %%
import io
import requests
import numpy as np
from transformers import pipeline

def detect_background_music_and_speech(youtube_video_url):
    # Download the YouTube video as an audio file.
    response = requests.get(youtube_video_url, stream=True)
    audio_file = io.BytesIO(response.content)

    # Convert the audio file to a NumPy array
    # element_size = np.dtype(np.int16).itemsize
    audio_array = np.frombuffer(audio_file.read(), dtype=np.int16)
    audio_array = audio_array.astype(np.float32) / np.iinfo(np.int16).max

    # Load the audio classification model from Hugging Face.
    model = pipeline("audio-classification", model="speechbrain/emotion-recognition-wav2vec2-IEMOCAP")

    # Perform classification using the model.
    results = model(audio_array)

    # Return the model's output.
    return results

if __name__ == "__main__":
    # Get the YouTube video URL from the user.
    youtube_video_url = "https://www.youtube.com/shorts/q2sVKKaKvys"

    # Detect background music and speech in the YouTube video.
    results = detect_background_music_and_speech(youtube_video_url)

    # Print the classification results.
    for segment in results:
        label = segment['label']
        #start_time = segment['start']
        #end_time = segment['end']
        confidence = segment['score']
        print(f"Label: {label}, Confidence: {confidence}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     260     try:
# --> 261         response.raise_for_status()
#     262     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/speechbrain/emotion-recognition-wav2vec2-IEMOCAP/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# ...

# %%
import io
import requests
import numpy as np
from transformers import pipeline

def detect_music_and_speech(youtube_video_url):
    # Download the YouTube video as an audio file.
    response = requests.get(youtube_video_url, stream=True)
    audio_file = io.BytesIO(response.content)

    # Convert the audio file to a NumPy array
    #element_size = np.dtype(np.int16).itemsize
    # audio_file = str(audio_file)
    # audio_str_enc = audio_file.encode()
    # bytes_np_dec = audio_str_enc.decode('unicode-escape').encode('ISO-8859-1')[2:-1]
    audio_array = np.frombuffer(audio_file.read(), dtype=np.int16)
    audio_array = audio_array.astype(np.float32) / np.iinfo(np.int16).max

    # Load the LLM model from Hugging Face.
    model = pipeline("audio-classification", model="facebook/wav2vec2-base-960h")

    # Perform classification using the model.
    results = model(audio_array)

    # Get the length of the audio file.
    duration_in_milliseconds = get_youtube_video_length(youtube_video_url)

    # Find the start and end times of the music segments.
    music_segments = []
    for segment in results:
        if segment["label"] == "music":
            music_segments.append((segment["start"], segment["end"]))

    # Find the start and end times of the speech segments.
    speech_segments = []
    for segment in results:
        if segment["label"] == "speech":
            speech_segments.append((segment["start"], segment["end"]))

    return music_segments, speech_segments, duration_in_milliseconds

if __name__ == "__main__":
    youtube_video_url = "https://www.youtube.com/watch?v=q2sVKKaKvys"

    music_segments, speech_segments, duration_in_milliseconds = detect_music_and_speech(youtube_video_url)

    print("The video length is {} milliseconds.".format(duration_in_milliseconds))

    print("The music segments are:")
    for music_segment in music_segments:
        print(f"Start: {music_segment[0]} End: {music_segment[1]}")

    print("The speech segments are:")
    for speech_segment in speech_segments:
        print(f"Start: {speech_segment[0]} End: {speech_segment[1]}")
# Out:
# ...
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['projector.bias', 'wav2vec2.masked_spec_embed', 'classifier.bias', 'classifier.weight', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-035bbbdd238f> in <cell line: 42>()
#      43     youtube_video_url = "https://www.youtube.com/watch?v=q2sVKKaKvys"
#      44
# ---> 45     music_segments, speech_segments, duration_in_milliseconds = detect_music_and_speech(youtube_video_url)
#      46
#      47     print("The video length is {} milliseconds.".format(duration_in_milliseconds))
#
# <ipython-input-1-035bbbdd238f> in detect_music_and_speech(youtube_video_url)
#      24
# ...

# %%
# !pip install torch accelerate torchaudio datasets

# %%
# !pip install --upgrade transformers

# %%
# !pip install git+https://github.com/huggingface/transformers.git
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-st2bddbv
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-st2bddbv
#   Resolved https://github.com/huggingface/transformers.git to commit eec5841e9f440c795fb9292d009675d97a14f983
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.32.0.dev0-py3-none-any.whl size=7459361 sha256=33012902d3f501f5b5509218173714870e11cbb387ba03ec81edbedb7e180981
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1aijoplg/wheels/e7/9c/5b/e1a9c8007c343041e61cc484433d512ea9274272e3fcbe7c16
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.31.0
#     Uninstalling transformers-4.31.0:
#       Successfully uninstalled transformers-4.31.0
# ...

# %%
from datasets import load_dataset

# %%
# English
stream_data = load_dataset("mozilla-foundation/common_voice_13_0", "en", split="test", streaming=True)
stream_data = stream_data.cast_column("audio", Audio(sampling_rate=16000))
en_sample = next(iter(stream_data))["audio"]["array"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-fcb0836832d3> in <cell line: 2>()
#       1 # English
# ----> 2 stream_data = load_dataset("mozilla-foundation/common_voice_13_0", "en", split="test", streaming=True)
#       3 stream_data = stream_data.cast_column("audio", Audio(sampling_rate=16000))
#       4 en_sample = next(iter(stream_data))["audio"]["array"]
#
# /usr/local/lib/python3.10/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2110
#    2111     # Create a dataset builder
# -> 2112     builder_instance = load_dataset_builder(
#    2113         path=path,
#    2114         name=name,
#
# ...

# %%
# !pip install label studio
# Out:
# ...
#   Using cached label-0.1.1.tar.gz (2.1 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached Studio-0.5.1.tar.gz (2.4 MB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
